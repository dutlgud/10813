# %% [markdown]
# <a href="https://colab.research.google.com/github/dutlgud/10813/blob/main/20260902.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프프로그래밍')
# Out:
# 재미있는 프로프로그래밍
# 10
# 3+7
# 10 20 30 정보 프프로그래밍

# %%
print('한양과학기술고등학교','1학년','여시형')
print('체질량 지수(BMI):',76 /(170*170)*10000)
# Out:
# 한양과학기술고등학교 1학년 여시형
# 체질량 지수(BMI): 26.297577854671278

# %%
c=90
d=3.141592
print(f'직각은{c}도,원주율은 {d:0.2f} 입니다.')
# Out:
# 직각은90도,원주율은 3.14 입니다.

# %%
print('동해 물과 \'백두산\'이')
print('마르도 닮도록')
print('하느님이 보우하사 \n우리나라 만세')
print('무궁화 삼천리', end=',')
print('화려 강산')
print('대한 사람,"대한"으로 길이 보전하세.')
print('2026','05','20', sep='-')
# Out:
# 동해 물과 '백두산'이
# 마르도 닮도록
# 하느님이 보우하사
# 우리나라 만세
# 무궁화 삼천리,화려 강산
# 대한 사람,"대한"으로 길이 보전하세.
# 2026-05-20

# %%
print(f'#########################\n [한양과학기술고등학교 학생증]\n 1 학번 :10813\n 2 성명 :여시형\n 3 소속 :스마트 전자과\n 위 사람은 본 학교의 학생임을 증명함\n#########################')
# Out:
# #########################
#  [한양과학기술고등학교 학생증]
#  1 학번 :10813
#  2 성명 :여시형
#  3 소속 :스마트 전자과
#  위 사람은 본 학교의 학생임을 증명함
# #########################
